# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

import src.functions as fn

rounds = [
 {
 'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
 'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
 'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
 'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
 'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
 },
 {
 'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
 'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
 'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
 'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
 'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
 },
 {
 'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
 'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
 'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
 'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
 'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
 },
 {
 'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
 'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
 'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
 'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
 'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
 },
 {
 'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
 'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
 'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
 'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
 'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
 }]

total_rondas = { 
 'Shadow': {'kills': 0, 'assists': 0, 'deaths': 0, 'MVP': 0, 'puntos': 0},
 'Blaze': {'kills': 0, 'assists': 0, 'deaths': 0, 'MVP': 0, 'puntos': 0},
 'Viper': {'kills': 0, 'assists': 0, 'deaths': 0, 'MVP': 0, 'puntos': 0},
 'Frost': {'kills': 0, 'assists': 0, 'deaths': 0, 'MVP': 0, 'puntos': 0},
 'Reaper': {'kills': 0, 'assists': 0, 'deaths': 0, 'MVP': 0, 'puntos': 0}
 }

ronda_act = {}

for round in rounds:
    ronda_act = fn.inicializar_ronda_act()
    ronda_act = fn.generar_tabla_ronda_act(round, ronda_act)

    print("\nJugador".ljust(10) + "Kills".ljust(10) + "Asistencias".ljust(15) + "Murio".ljust(10) + "Puntos".ljust(10))
    print("-" * 55)

    fn.imprimir_estadisticas_ronda(ronda_act)

    nombre_MVP, puntos_MVP = fn.determinar_MVP(ronda_act)
    print(f"\nMVP de la ronda: {nombre_MVP} con {puntos_MVP} puntos.")
    print("." * 55)

    total_rondas = fn.generar_tabla_total(ronda_act, total_rondas, nombre_MVP)

print("\nJugador".ljust(10) + "Kills".ljust(10) + "Asistencias".ljust(15) + "Muertes".ljust(10) + "MVP".ljust(10) + "Puntos".ljust(10))
print("-" * 55)

lista_ordenada = sorted(total_rondas.items(), key=lambda x: x[1]['puntos'], reverse=True)
total_rondas = dict(lista_ordenada)

fn.imprimir_estadisticas_finales(total_rondas)
# Out:
# Jugador  Kills     Asistencias    Murio     Puntos
# -------------------------------------------------------
# Shadow    2         1              Si        6
# Blaze     1         0              No        3
# Viper     1         2              Si        4
# Frost     0         1              No        1
# Reaper    1         1              No        4
#
# MVP de la ronda: Shadow con 6 puntos.
# .......................................................
#
# Jugador  Kills     Asistencias    Murio     Puntos
# -------------------------------------------------------
# Shadow    0         2              No        2
# Blaze     2         0              Si        5
# Viper     1         1              No        4
# Frost     2         1              Si        6
# Reaper    0         1              No        1
#
# MVP de la ronda: Frost con 6 puntos.
# .......................................................
#
# Jugador  Kills     Asistencias    Murio     Puntos
# ...
